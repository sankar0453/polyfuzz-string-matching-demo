# %%
# !pip install polyfuzz[flair]
# Out:
# Collecting polyfuzz[flair]
#   Downloading polyfuzz-0.4.2-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (1.11.4)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (2.0.3)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (4.66.4)
# Requirement already satisfied: joblib>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (1.4.2)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (3.7.1)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (0.13.1)
# Collecting rapidfuzz>=0.13.1 (from polyfuzz[flair])
#   Downloading rapidfuzz-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (1.2.2)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from polyfuzz[flair]) (2.3.0+cu121)
# Collecting flair>=0.7 (from polyfuzz[flair])
#   Downloading flair-0.13.1-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 27.4 MB/s eta 0:00:00
# Collecting boto3>=1.20.27 (from flair>=0.7->polyfuzz[flair])
#   Downloading boto3-1.34.113-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 5.3 MB/s eta 0:00:00
# Collecting bpemb>=0.3.2 (from flair>=0.7->polyfuzz[flair])
#   Downloading bpemb-0.3.5-py3-none-any.whl (19 kB)
# Collecting conllu>=4.0 (from flair>=0.7->polyfuzz[flair])
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Collecting deprecated>=1.2.13 (from flair>=0.7->polyfuzz[flair])
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ftfy>=6.1.0 (from flair>=0.7->polyfuzz[flair])
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (5.1.0)
# Requirement already satisfied: gensim>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (4.3.2)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (0.23.1)
# Collecting janome>=0.4.2 (from flair>=0.7->polyfuzz[flair])
#   Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 35.1 MB/s eta 0:00:00
# Collecting langdetect>=1.0.9 (from flair>=0.7->polyfuzz[flair])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 43.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (4.9.4)
# Requirement already satisfied: more-itertools>=8.13.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (10.1.0)
# Collecting mpld3>=0.3 (from flair>=0.7->polyfuzz[flair])
#   Downloading mpld3-0.5.10-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 19.0 MB/s eta 0:00:00
# Collecting pptree>=3.1 (from flair>=0.7->polyfuzz[flair])
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (2.8.2)
# Collecting pytorch-revgrad>=0.2.0 (from flair>=0.7->polyfuzz[flair])
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (2023.12.25)
# Collecting segtok>=1.5.11 (from flair>=0.7->polyfuzz[flair])
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting sqlitedict>=2.0.0 (from flair>=0.7->polyfuzz[flair])
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (0.9.0)
# Collecting transformer-smaller-training-vocab>=0.2.3 (from flair>=0.7->polyfuzz[flair])
#   Downloading transformer_smaller_training_vocab-0.4.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: transformers[sentencepiece]<5.0.0,>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.7->polyfuzz[flair]) (4.41.0)
# Collecting urllib3<2.0.0,>=1.0.0 (from flair>=0.7->polyfuzz[flair])
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 16.2 MB/s eta 0:00:00
# Collecting wikipedia-api>=0.5.7 (from flair>=0.7->polyfuzz[flair])
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Collecting semver<4.0.0,>=3.0.0 (from flair>=0.7->polyfuzz[flair])
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->polyfuzz[flair]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->polyfuzz[flair]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->polyfuzz[flair]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->polyfuzz[flair]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->polyfuzz[flair]) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->polyfuzz[flair]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->polyfuzz[flair]) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->polyfuzz[flair]) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->polyfuzz[flair]) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->polyfuzz[flair]) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->polyfuzz[flair]) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->polyfuzz[flair]) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->polyfuzz[flair]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->polyfuzz[flair]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->polyfuzz[flair]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->polyfuzz[flair]) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.4.0->polyfuzz[flair])
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->polyfuzz[flair]) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->polyfuzz[flair])
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 42.7 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.113 (from boto3>=1.20.27->flair>=0.7->polyfuzz[flair])
#   Downloading botocore-1.34.113-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 64.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.27->flair>=0.7->polyfuzz[flair])
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.20.27->flair>=0.7->polyfuzz[flair])
#   Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair>=0.7->polyfuzz[flair]) (2.31.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair>=0.7->polyfuzz[flair]) (0.1.99)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->flair>=0.7->polyfuzz[flair]) (1.14.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy>=6.1.0->flair>=0.7->polyfuzz[flair]) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair>=0.7->polyfuzz[flair]) (4.12.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->flair>=0.7->polyfuzz[flair]) (6.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair>=0.7->polyfuzz[flair]) (6.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect>=1.0.9->flair>=0.7->polyfuzz[flair]) (1.16.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair>=0.7->polyfuzz[flair]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair>=0.7->polyfuzz[flair]) (0.4.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair>=0.7->polyfuzz[flair]) (3.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->polyfuzz[flair]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->polyfuzz[flair]) (1.3.0)
# Collecting accelerate>=0.21.0 (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair>=0.7->polyfuzz[flair])
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 35.7 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.4.0->flair>=0.7->polyfuzz[flair]) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair>=0.7->polyfuzz[flair]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair>=0.7->polyfuzz[flair]) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair>=0.7->polyfuzz[flair]) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair>=0.7->polyfuzz[flair]) (1.7.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[sentencepiece]<5.0.0,>=4.18.0->flair>=0.7->polyfuzz[flair]) (5.9.5)
# Building wheels for collected packages: langdetect, pptree, sqlitedict
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=bffe67b9d2f5e2d09f6cf6406134f4d7c7ab04bab9bb4c0813fbf031fc5a76be
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4609 sha256=f30a58dbecaff76bbbda36593259827ca004548ae56d6498f606c21056eac199
#   Stored in directory: /root/.cache/pip/wheels/9f/b6/0e/6f26eb9e6eb53ff2107a7888d72b5a6a597593956113037828
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=0853582731dc92da2cde20b95c70a2074157a042124f51ceaea1fed869799ce0
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built langdetect pptree sqlitedict
# Installing collected packages: sqlitedict, pptree, janome, urllib3, semver, segtok, rapidfuzz, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, langdetect, jmespath, ftfy, deprecated, conllu, nvidia-cusparse-cu12, nvidia-cudnn-cu12, botocore, wikipedia-api, s3transfer, nvidia-cusolver-cu12, mpld3, bpemb, polyfuzz, boto3, pytorch-revgrad, accelerate, transformer-smaller-training-vocab, flair
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed accelerate-0.30.1 boto3-1.34.113 botocore-1.34.113 bpemb-0.3.5 conllu-4.5.3 deprecated-1.2.14 flair-0.13.1 ftfy-6.2.0 janome-0.5.0 jmespath-1.0.1 langdetect-1.0.9 mpld3-0.5.10 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 polyfuzz-0.4.2 pptree-3.1 pytorch-revgrad-0.2.0 rapidfuzz-3.9.1 s3transfer-0.10.1 segtok-1.5.11 semver-3.0.2 sqlitedict-2.1.0 transformer-smaller-training-vocab-0.4.0 urllib3-1.26.18 wikipedia-api-0.6.0

# %% [markdown]
# ## Imports

# %%
from polyfuzz import PolyFuzz
from polyfuzz.models import Embeddings
from flair.embeddings import TransformerWordEmbeddings

# %% [markdown]
# ## Edit Distance based Similarity Score

# %%
list_1 = ["apple", "amazon", "google"]
list_2 = ["search", "juice", "forest"]

# %%
model = PolyFuzz('EditDistance')
model.match(list_1,list_2)

# %%
model.get_matches()
# Out:
#      From      To  Similarity
# 0   apple   juice    0.200000
# 1  amazon  search    0.166667
# 2  google  forest    0.333333

# %% [markdown]
# ## Bert Based Similarity

# %%
embeddings = TransformerWordEmbeddings('bert-base-multilingual-cased')
bert = Embeddings(embeddings)

bert_model = PolyFuzz(bert)
bert_model.match(list_1, list_2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %%
bert_model = PolyFuzz(bert)
bert_model.match(list_1, list_2)

# %%
bert_model.get_matches()
# Out:
#      From      To  Similarity
# 0   apple   juice       0.635
# 1  amazon  forest       0.506
# 2  google  search       0.655

# %%
bert_model.get_matches()

# %% [markdown]
# ## Domain requirement

# %%
list_3=["A-110"]
list_4=["a 1:10"]
bert_model.match(list_3, list_4)
bert_model.get_matches()
# Out:
#     From      To  Similarity
# 0  A-110  a 1:10       0.325

# %%
list_3=["BMS-986015"]
list_4=["BMS 986015"]
bert_model.match(list_3, list_4)
bert_model.get_matches()
# Out:
#          From          To  Similarity
# 0  BMS-986015  BMS 986015       0.799

# %%
list_3=["BMS-986015"]
list_4=["BMS986015"]
bert_model.match(list_3, list_4)
bert_model.get_matches()
# Out:
#          From         To  Similarity
# 0  BMS-986015  BMS986015       0.932

# %%
list_3=["BMS-986015","BMS986015"]
list_4=["BMS 986015"]
bert_model.match(list_3, list_4)
bert_model.get_matches()
# Out:
#          From          To  Similarity
# 0  BMS-986015  BMS 986015       0.799
# 1   BMS986015  BMS 986015       0.816
